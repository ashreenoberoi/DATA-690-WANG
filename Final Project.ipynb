# %% [markdown]
# Project 1:
#
# **What is your issue of interest (provide sufficient background information)?**
#
# I have been working on very serious topics and I wanted to have fun with this dataset. I love watching movies and I judge movies on the basis of the amount they earn and what better dataset to work with movie and their earnings
#
# **Why is this issue important to you and/or to others?**
#
# It is very fun to work with and you never know what you learn out of it or what maybe the top earning movies of all time. It motivates people to get into the film industry when they see how much money they can possibily earn. It is a good motivaitonal factor and for people who have not watched the top movies of all time, this analysis is for you.
#
#
#
# **What questions do you have in mind and would like to answer?**
#
#
# - I am going to compare the budget and the total gross income and see which team made the highest profit
# - I believe that people go to the movie theatre more in summers only because it is too hot and they can't walk on streets, but let's find out.
# - Which year had the most worldwide colection. This would also give us the most numbers of hit in that particular year
# - Top 5 most successful movies of all time.
# - Is the higest paid movie also has the most internation gross earning?
#
#
#
# **Where do you get the data to help answer your questions?**
#
# I found this webisite online that had the data. I copied it and made an excel sheet for it.
# The link is https://www.statcrunch.com/app/index.php?dataid=2188684
#
# **What will be your unit of analysis (for example, patient, organization, or country)? Roughly how many units (observations) do you expect to analyze**
#
# I will be using all the variables in the dataset. The below are the names of the variable
#
# - Movie
# - Month
# - Year
# - Budget
# - Domestic Gross
# - Worldwide Gross
#
# **What variables/measures do you plan to use in your analysis (variables should be tied to the questions in #3)?**
#
#
# I will be using 6 variables or more and my technique to use mathematical tools to find basic analysis.
#
#
# **What kinds of techniques do you plan to use (for example, summary statistics, scatter plot, bar chart, chi-squared test)?**
# I will be using different types of bar graphs to make it easy to analyze

# %% [markdown]
# Let's import Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns; sns.set()
import datetime as dt
import time

# %% [markdown]
# Let's load the dataset

# %%
df1 = pd.read_excel('movie openings.xlsx', sheetname='Sheet1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %% [markdown]
# Let's explore the data by printing the shape and size

# %%
df1.columns
# Out:
# Index(['Movie', 'Month', 'Day', 'Year', 'Budget($M)', 'Domestic Gross($M)',
#        'Worldwide Gross($M)'],
#       dtype='object')

# %%
df1.shape
# Out:
# (5222, 7)

# %% [markdown]
# To begin cleaning, let's see if there are any NAN or null values.

# %%
df1.isnull().any()
# Out:
# Movie                  False
# Month                  False
# Day                    False
# Year                   False
# Budget($M)             False
# Domestic Gross($M)     False
# Worldwide Gross($M)    False
# dtype: bool

# %% [markdown]
# "False" means that there is no null value and that half work is done and we can start analysing the dataset

# %% [markdown]
# **Question 1: Top 5 most successful movies of all time**.
#
# For this I am going to sough the dataset on the basis of the Worldwide Gross collection and print the first 5 to see which are the top 5 movies of all time

# %% [markdown]
# Sought the dataset in decending order on the basis of one column

# %%
final_df = df1.sort_values(by=['Worldwide Gross($M)'], ascending=False)

# %% [markdown]
# Just for the information, all the numbers are divide by $1 million to make it easy to analyze. For example if the number is 425.0 it means it is 425 million dollars

# %%
final_df.head(5)
# Out:
#                                   Movie Month  Day  Year  Budget($M)  \
# 0                                Avatar   Dec   18  2009       425.0
# 1                               Titanic   Dec   19  1997       200.0
# 2  Star Wars Ep. VII: The Force Awakens   Dec   18  2015       306.0
# 3                        Jurassic World   Jun   12  2015       215.0
# 4                          The Avengers   May    4  2012       225.0
#
#    Domestic Gross($M)  Worldwide Gross($M)
# 0          760.507625          2783.918982
# 1          659.363944          2208.208395
# 2          936.662225          2058.662225
# 3          652.270625          1671.713208
# 4          623.279547          1519.479547

# %% [markdown]
# **Question 2: Which year had the most worldwide colection**
#
# For this let's groupby the Year and the Worldwide gross and then plot it

# %%
df1.groupby('Year')['Worldwide Gross($M)'].sum()
# Out:
# Year
# 1915       11.000000
# 1916        8.000000
# 1920        3.000000
# 1925       31.000000
# 1929        4.358000
# 1931        0.900000
# 1933       14.281650
# 1934        2.500000
# 1935        3.202000
# 1936        5.438049
# 1937      184.925485
# 1938        8.000000
# 1939      433.280159
# 1940      182.792000
# 1942      276.000000
# 1943       15.825500
# 1944        5.500000
# 1945       27.132000
# 1946       79.233650
# 1947        7.800000
# 1948       11.968000
# 1949       13.200000
# 1950      271.591415
# 1951       56.022000
# 1952       51.200000
# 1953      185.200000
# 1954       52.800000
# 1955        7.000000
# 1956      170.574956
# 1957       44.314685
#             ...
# 1989     2716.119858
# 1990     4062.274076
# 1991     3063.610857
# 1992     4332.522874
# 1993     4328.018838
# 1994     7255.175057
# 1995     7632.612708
# 1996     8604.961323
# 1997    10848.898941
# 1998    10051.683570
# 1999    12576.395552
# 2000    13159.463079
# ...

# %%
df1.groupby('Year')['Worldwide Gross($M)'].sum().plot(kind='bar',figsize=(50, 15), fontsize=20)
plt.xlabel('Year', fontsize=20)
plt.ylabel('Worldwide Gross($M)', fontsize=50)
plt.title('Total Worldwide Gross($M)', fontsize=50)
# Out:
# Text(0.5, 1.0, 'Total Worldwide Gross($M)')

# %% [markdown]
# It is a strange analysis. It shows that 2018 did not have alot of collection to which I am assuming that the dataset does not have all the movies from 2018 so I am not going to consider that year. 2015 and 2016 are almost the same which means that this year the most number of successful movies were realeased. It was a year of Starwars and Jurassic World. I am a huge fan of Star Wars so I would give them that.

# %% [markdown]
# **Question 3 LI believe that people go to the movie theatre more in summers only because it is too hot and they can't walk on streets, but let's find out.**
#
# I used to go to the movies all the time because it is too hot to go to a park of to walk on streets. It is too hot for everything but to go to the movies so let's see if everyone agrees with me

# %%
df1.groupby('Month')['Worldwide Gross($M)'].sum()
# Out:
# Month
# Apr    23979.730828
# Aug    28444.287740
# Dec    71684.700941
# Feb    25714.141041
# Jan    15785.771701
# Jul    59083.914276
# Jun    62515.995754
# Mar    33179.465603
# May    63003.393343
# Nov    60366.185447
# Oct    27450.728568
# Sep    21929.083900
# Name: Worldwide Gross($M), dtype: float64

# %%
df1.groupby('Month')['Worldwide Gross($M)'].sum().plot(kind='bar',figsize=(50, 15), fontsize=20)
plt.xlabel('Year', fontsize=20)
plt.ylabel('Worldwide Gross($M)', fontsize=50)
plt.title('Total Worldwide Gross($M)', fontsize=50)
# Out:
# Text(0.5, 1.0, 'Total Worldwide Gross($M)')

# %% [markdown]
# I am wrong again. It seems like December is the time when people go out alot. I forgot to take into account that it is a holiday season so people might go to the movies but I am not completely wrong because the second and the thirs highest is summer. If we combine winter and summer, there are more collection in the summer time than winters

# %% [markdown]
# **Question 4: I am going to compare the budget and the total gross income and see which team made the highest profit**
#
# A movie is onlt profitable when the gross collection is more than the budget. Now it doesn't matter how much the mobie earns but the fact that how much did it earn over the buget.
#
# For that let's add another column and substract the Worldwide collection with the budget

# %%
df1['Profit'] = df1['Worldwide Gross($M)'] - df1['Budget($M)']

# %%
df1.head(5)
# Out:
#                                   Movie Month  Day  Year  Budget($M)  \
# 0                                Avatar   Dec   18  2009       425.0
# 1                               Titanic   Dec   19  1997       200.0
# 2  Star Wars Ep. VII: The Force Awakens   Dec   18  2015       306.0
# 3                        Jurassic World   Jun   12  2015       215.0
# 4                          The Avengers   May    4  2012       225.0
#
#    Domestic Gross($M)  Worldwide Gross($M)       Profit
# 0          760.507625          2783.918982  2358.918982
# 1          659.363944          2208.208395  2008.208395
# 2          936.662225          2058.662225  1752.662225
# 3          652.270625          1671.713208  1456.713208
# 4          623.279547          1519.479547  1294.479547

# %% [markdown]
# AVATAR is proven to be the biggest hit and to be honest , I have not seen that movie. It is a great learning for me because the top 5 movies are the ones I never liked, I am just different from the majority then.

# %% [markdown]
# **Question 5 : Is the higest paid movie also has the most internation gross earning?**
#
# With all the analysis , AVATAR has proved to have highest earning and profit but is it as success in the international market as it is in domestic.
#
# For this , lets substract the Worldwide gross with the domestic gross and find out

# %%
df1['Internation Earning'] = df1['Worldwide Gross($M)'] - df1['Domestic Gross($M)']

# %%
df1.head(5)
# Out:
#                                   Movie Month  Day  Year  Budget($M)  \
# 0                                Avatar   Dec   18  2009       425.0
# 1                               Titanic   Dec   19  1997       200.0
# 2  Star Wars Ep. VII: The Force Awakens   Dec   18  2015       306.0
# 3                        Jurassic World   Jun   12  2015       215.0
# 4                          The Avengers   May    4  2012       225.0
#
#    Domestic Gross($M)  Worldwide Gross($M)       Profit  Internation Earning
# 0          760.507625          2783.918982  2358.918982          2023.411357
# 1          659.363944          2208.208395  2008.208395          1548.844451
# 2          936.662225          2058.662225  1752.662225          1122.000000
# 3          652.270625          1671.713208  1456.713208          1019.442583
# 4          623.279547          1519.479547  1294.479547           896.200000

# %% [markdown]
# And here we are, AVATAR is still on the top. I think I need to watch this movie.
#
#
#
# **Conclusion**: It turns out that the top earning movies are the ones that have the highest income, highest profits not even domistically but it is also a success internationally
