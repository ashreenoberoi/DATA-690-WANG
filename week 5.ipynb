# %%
import pandas as pd

# %%
dframe= pd.read_csv("a.csv")

# %%
dframe
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# 5       100751   105100    1051
# 6       100760   100700    1007
# 7       100812   100800    1008
# 8       100830   831000    8310
# 9       100858   100900    1009
# 10      100937   101200    1012
# 11      101028  1218200   12182
# 12      101073  1055400   10554
# 13      101116  1303906   13039
# 14      101143   101500    1015
# 15      101161   106000    1060
# 16      101189   100300    1003
# 17      101240   101700    1017
# 18      101277  4187200   41872
# 19      101286   101800    1018
# 20      101295   787100    7871
# 21      101301   569900    5699
# 22      101365   962107    9621
# 23      101435   101900    1019
# 24      101453  2199700   21997
# 25      101462   526000    5260
# 26      101471  3002500   30025
# 27      101480   102000    1020
# ...

# %%
dframe.shape
# Out:
# (7112, 1986)

# %%
dframe.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %%
dframe.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %%
dframe.sample()
# Out:
#       UNITID    OPEID  OPEID6                             INSTNM    CITY  \
# 6033  476823  4202600   42026  New Dimensions Beauty Academy Inc  Parker
#
#      STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 6033     CO  80138-9801           NaN      NaN     NaN  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN  UG12MN  G12MN  \
# 6033                           NaN       0.6667           1.0    88.0    NaN
#
#       SCUGFFN  POOLYRS_FTFTAIDPCT  FTFTPCTPELL_POOLED_SUPP  \
# 6033     12.0                 NaN                      NaN
#
#       FTFTPCTFLOAN_POOLED_SUPP  SCUGFFN_POOLED
# 6033                       NaN             NaN
#
# [1 rows x 1986 columns]

# %%
list(dframe.columns.values)
# Out:
# ['UNITID',
#  'OPEID',
#  'OPEID6',
#  'INSTNM',
#  'CITY',
#  'STABBR',
#  'ZIP',
#  'ACCREDAGENCY',
#  'INSTURL',
#  'NPCURL',
#  'SCH_DEG',
#  'HCM2',
#  'MAIN',
#  'NUMBRANCH',
#  'PREDDEG',
#  'HIGHDEG',
#  'CONTROL',
#  'ST_FIPS',
#  'REGION',
#  'LOCALE',
#  'LOCALE2',
#  'LATITUDE',
#  'LONGITUDE',
#  'CCBASIC',
#  'CCUGPROF',
#  'CCSIZSET',
#  'HBCU',
#  'PBI',
#  'ANNHI',
#  'TRIBAL',
#  'AANAPII',
#  'HSI',
#  'NANTI',
#  'MENONLY',
#  'WOMENONLY',
#  'RELAFFIL',
#  'ADM_RATE',
#  'ADM_RATE_ALL',
#  'SATVR25',
#  'SATVR75',
#  'SATMT25',
#  'SATMT75',
#  'SATWR25',
#  'SATWR75',
#  'SATVRMID',
#  'SATMTMID',
#  'SATWRMID',
#  'ACTCM25',
#  'ACTCM75',
#  'ACTEN25',
#  'ACTEN75',
#  'ACTMT25',
#  'ACTMT75',
#  'ACTWR25',
#  'ACTWR75',
#  'ACTCMMID',
#  'ACTENMID',
#  'ACTMTMID',
#  'ACTWRMID',
#  'SAT_AVG',
#  'SAT_AVG_ALL',
#  'PCIP01',
#  'PCIP03',
#  'PCIP04',
#  'PCIP05',
#  'PCIP09',
#  'PCIP10',
#  'PCIP11',
#  'PCIP12',
#  'PCIP13',
#  'PCIP14',
#  'PCIP15',
# ...

# %%
df = pd.read_csv("a.csv", usecols = ['UNITID','INSTNM','CITY','ZIP','STABBR','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10'])

# %%
df

# %%
xl = pd.ExcelFile("B.xlsx")

# %%
xl.sheet_names
# Out:
# ['README',
#  'ChangeLog',
#  'glossary',
#  'institution_data_dictionary',
#  'institution_cohort_map',
#  'most_recent_inst_cohort_map',
#  'FieldOfStudy_data_dictionary',
#  'FieldOfStudy_cohort_map']

# %%
df.head(5)
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0    0.9027   4824.0         9857.0              NaN
# 1    0.9181  12866.0         8328.0              NaN
# 2       NaN    318.0         6900.0              NaN
# 3    0.8123   6917.0        10280.0              NaN
# 4    0.9787   4189.0        11068.0              NaN

# %%
df.tail(5)
# Out:
#         UNITID                                             INSTNM  \
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                  CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7107             Yuma     AZ  853656900       NaN   NaN            NaN
# 7108         San Jose     CA      95113       NaN   NaN            NaN
# 7109      Bakersfield     CA      93301       NaN   NaN            NaN
# 7110           Malden     MA  021480000       NaN   NaN            NaN
# 7111  Fort Lauderdale     FL      33309       NaN   NaN        22575.0
#
#       MN_EARN_WNE_P10
# 7107              NaN
# 7108              NaN
# 7109              NaN
# 7110              NaN
# 7111              NaN

# %%
df.sample()
# Out:
#       UNITID             INSTNM     CITY STABBR         ZIP  ADM_RATE    UGDS  \
# 1556  166018  Hampshire College  Amherst     MA  01002-5001    0.6282  1264.0
#
#       TUITIONFEE_IN  MN_EARN_WNE_P10
# 1556        51608.0              NaN

# %%
df.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0    0.9027   4824.0         9857.0              NaN
# 1    0.9181  12866.0         8328.0              NaN
# 2       NaN    318.0         6900.0              NaN
# 3    0.8123   6917.0        10280.0              NaN
# 4    0.9787   4189.0        11068.0              NaN

# %%
df.loc[df['INSTNM'] == 'UMBC']
# Out:
# Empty DataFrame
# Columns: [UNITID, INSTNM, CITY, STABBR, ZIP, ADM_RATE, UGDS, TUITIONFEE_IN, MN_EARN_WNE_P10]
# Index: []

# %%
df.loc[df['INSTNM'] == 'University of Maryland Baltimore County']
# Out:
# Empty DataFrame
# Columns: [UNITID, INSTNM, CITY, STABBR, ZIP, ADM_RATE, UGDS, TUITIONFEE_IN, MN_EARN_WNE_P10]
# Index: []

# %%
df.loc[df['INSTNM'] == 'University Of Maryland, Baltimore County']
# Out:
# Empty DataFrame
# Columns: [UNITID, INSTNM, CITY, STABBR, ZIP, ADM_RATE, UGDS, TUITIONFEE_IN, MN_EARN_WNE_P10]
# Index: []

# %%
df.tail(5)
# Out:
#         UNITID                                             INSTNM  \
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                  CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7107             Yuma     AZ  853656900       NaN   NaN            NaN
# 7108         San Jose     CA      95113       NaN   NaN            NaN
# 7109      Bakersfield     CA      93301       NaN   NaN            NaN
# 7110           Malden     MA  021480000       NaN   NaN            NaN
# 7111  Fort Lauderdale     FL      33309       NaN   NaN        22575.0
#
#       MN_EARN_WNE_P10
# 7107              NaN
# 7108              NaN
# 7109              NaN
# 7110              NaN
# 7111              NaN

# %%
df.sort_index(axis=1)
# Out:
#       ADM_RATE              CITY  \
# 0       0.9027            Normal
# 1       0.9181        Birmingham
# 2          NaN        Montgomery
# 3       0.8123        Huntsville
# 4       0.9787        Montgomery
# 5       0.5330        Tuscaloosa
# 6          NaN    Alexander City
# 7          NaN            Athens
# 8       0.8240        Montgomery
# 9       0.8393            Auburn
# 10      0.6186        Birmingham
# 11         NaN       Phenix City
# 12         NaN             Selma
# 13         NaN        Montgomery
# 14         NaN        Enterprise
# 15         NaN       Bay Minette
# 16      0.5101        Montgomery
# 17         NaN           Gadsden
# 18         NaN       Albertville
# 19         NaN            Dothan
# 20         NaN        Hanceville
# 21         NaN             Selma
# 22      0.7570        Birmingham
# 23      0.5598        Montgomery
# 24      1.0000          Florence
# 25         NaN        Huntsville
# 26         NaN        Deatsville
# ...

# %%
df.loc[df['INSTNM'] == 'University of Maryland, College Park']
# Out:
# Empty DataFrame
# Columns: [UNITID, INSTNM, CITY, STABBR, ZIP, ADM_RATE, UGDS, TUITIONFEE_IN, MN_EARN_WNE_P10]
# Index: []

# %%
df.sort_values('INSTNM')
df.sort_values('INSTNM', ascending=False)
# Out:
#         UNITID                                             INSTNM  \
# 5147    446534         eClips School of Cosmetology and Barbering
# 2735    204255                                 Zane State College
# 6401    486248                                                ZMS
# 5365    451237                                     Z Hair Academy
# 4486    413820                           Yukon Beauty College Inc
# 521     126119                                       Yuba College
# 2814    206695                        Youngstown State University
# 870     141361                               Young Harris College
# 3265    218991                             York Technical College
# 4562    418409  York County School of Technology-Adult & Conti...
# 6996  42044001  York County Community College - Sanford Instru...
# 4619    420440                      York County Community College
# 3187    217059                       York College of Pennsylvania
# ...

# %%
df.loc[df['ZIP'] == '21250']
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %%
df.loc[df['ZIP'] == '20742']
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %%
df.loc[df['INSTNM'] == 'Loyola University Maryland']
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %%
df.loc[df['ZIP'] == '21218']
# Out:
#       UNITID                               INSTNM       CITY STABBR    ZIP  \
# 5834  461379  Holistic Massage Training Institute  Baltimore     MD  21218
#
#       ADM_RATE  UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 5834       NaN  59.0            NaN              NaN

# %%
df.loc[df['STABBR'] == 'MD']
# Out:
#         UNITID                                             INSTNM  \
# 1446    161651                Aesthetics Institute of Cosmetology
# 1447    161688                       Allegany College of Maryland
# 1448    161767                     Anne Arundel Community College
# 1449    161776                          Brightwood College-Towson
# 1450    161800                                Award Beauty School
# 1451    161855                    Baltimore Studio of Hair Design
# 1452    161864                   Baltimore City Community College
# 1453    161873                            University of Baltimore
# 1454    162007                             Bowie State University
# 1455    162061                      Capitol Technology University
# 1456    162104                                      Cecil College
# 1457    162122                       College of Southern Maryland
# 1458    162168                                 Chesapeake College
# ...

# %%
df1.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0    0.9027   4824.0         9857.0              NaN
# 1    0.9181  12866.0         8328.0              NaN
# 2       NaN    318.0         6900.0              NaN
# 3    0.8123   6917.0        10280.0              NaN
# 4    0.9787   4189.0        11068.0              NaN

# %%
df1 = df.copy()

# %%
# state_id= df1[df1['STABBR']=='MD'or df1['STABBR']=='Virgina' or df1['STABBR']=='Virgina' or df1['STABBR']=='DC' or df1['STABBR']=='DE'or df1['STABBR']=='PA' ]
states = ['MD', 'Virgina', 'DC', 'DE','PA']
state_id= df1[df1.STABBR.isin(states)]
state_id
# Out:
#         UNITID                                             INSTNM  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...
# 635     130873                          Dawn Career Institute LLC
# 636     130907         Delaware Technical Community College-Terry
# 637     130934                          Delaware State University
# 638     130943                             University of Delaware
# 639     130989                              Goldey-Beacom College
# 640     131061        Schilling-Douglas School of Hair Design LLC
# 641     131098                                     Wesley College
# 642     131113                              Wilmington University
# 643     131159                                American University
# 644     131283                 The Catholic University of America
# 645     131399             University of the District of Columbia
# 646     131405  Pontifical Faculty of the Immaculate Conceptio...
# ...

# %%
df1.to_csv(r'C:\Users\Sunny\Desktop\b.csv', sep = ';')

# %%
df.loc[df['STABBR'] == 'DC']
# Out:
#         UNITID                                             INSTNM        CITY  \
# 643     131159                                American University  Washington
# 644     131283                 The Catholic University of America  Washington
# 645     131399             University of the District of Columbia  Washington
# 646     131405  Pontifical Faculty of the Immaculate Conceptio...  Washington
# 647     131450                               Gallaudet University  Washington
# 648     131469                       George Washington University  Washington
# 649     131496                              Georgetown University  Washington
# 650     131520                                  Howard University  Washington
# 651     131803            Strayer University-District of Columbia  Washington
# 652     131830             National Conservatory of Dramatic Arts  Washington
# 653     131876                      Trinity Washington University  Washington
# ...

# %%
df.loc[df['STABBR'] == 'DE']
# Out:
#         UNITID                                             INSTNM        CITY  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...       Lewes
# 635     130873                          Dawn Career Institute LLC      Newark
# 636     130907         Delaware Technical Community College-Terry       Dover
# 637     130934                          Delaware State University       Dover
# 638     130943                             University of Delaware      Newark
# 639     130989                              Goldey-Beacom College  Wilmington
# 640     131061        Schilling-Douglas School of Hair Design LLC      Newark
# 641     131098                                     Wesley College       Dover
# 642     131113                              Wilmington University  New Castle
# 4729    432524                 Delaware College of Art and Design  Wilmington
# 4917    441362        Harris School of Business-Wilmington Campus  Wilmington
# ...

# %%
df.loc[df['STABBR'] == 'PA']
# Out:
#         UNITID                                             INSTNM  \
# 2933    210474             Jolie Hair and Beauty Academy-Hazleton
# 2934    210492               Bryn Athyn College of the New Church
# 2935    210508                              Academy of Vocal Arts
# 2936    210571                                   Albright College
# 2937    210599                            All-State Career School
# 2938    210605              Community College of Allegheny County
# 2939    210669                                  Allegheny College
# 2940    210711                              The  Beauty Institute
# 2941    210739                                 DeSales University
# 2942    210748                          Altoona Beauty School Inc
# 2943    210775                                Alvernia University
# 2944    210784                        The Beauty Institute-Ambler
# 2945    210809             American College of Financial Services
# ...
