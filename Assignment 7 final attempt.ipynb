# %% [markdown]
# Import libraries

# %%
import os, sys
import glob
import pandas as pd

# %% [markdown]
# <2>
# Display the current workin directory using os.getcwd()
# you would need to import a standard Python library called os which stands for operating system,
# so place that import statement in the previous cell.
# Since your notebook and your data files are not in # the same folder,
# you want to make sure what is the current working folder and
# how to access a data file in a different folder

# %%
path =os.getcwd()
print (path)
# Out:
# C:\Users\Sunny\Desktop\data 690\CollegeScorecard_Raw_Data\CollegeScorecard_Raw_Data

# %% [markdown]
#  os library has a method call listdir which generates a list of files in a directory/folder.
# use this method to assign the contents (list of file names) of the data folder to a variable and display it.
# You can use ../ construct to traverse to the parent folder and then to another foloder parallel to the current folder

# %%
extension = 'csv'
result = glob.glob('*.{}'.format(extension))
print(result)
# Out:
# ['MERGED1996_97_PP.csv', 'MERGED1997_98_PP.csv', 'MERGED1998_99_PP.csv', 'MERGED1999_00_PP.csv', 'MERGED2000_01_PP.csv', 'MERGED2001_02_PP.csv', 'MERGED2002_03_PP.csv', 'MERGED2003_04_PP.csv', 'MERGED2004_05_PP.csv', 'MERGED2005_06_PP.csv', 'MERGED2006_07_PP.csv', 'MERGED2007_08_PP.csv', 'MERGED2008_09_PP.csv', 'MERGED2009_10_PP.csv', 'MERGED2010_11_PP.csv', 'MERGED2011_12_PP.csv', 'MERGED2012_13_PP.csv', 'MERGED2013_14_PP.csv', 'MERGED2014_15_PP.csv', 'MERGED2015_16_PP.csv', 'MERGED2016_17_PP.csv', 'MERGED2017_18_PP.csv', 'MERGED2018_19_PP.csv']

# %% [markdown]
# Now that you have a clean list of the yearly files, you want to loop through them
# and read them into a dataframe one at a time. You only load six columns:
# ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"].
# You should use "usecols" option of Pandas to avoid reading unwanted columns.

# %%
frames=[]
for i in result:
    df = pd.read_csv(i, usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN","ZIP"])
    frames.append(df)
print(frames)

# %% [markdown]
# You would use an empty list and append the yearly dataframes to the list.
# After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a
# new single data frame

# %%
fin = pd.concat(frames)

# %%
fin
# Out:
#         UNITID                                             INSTNM STABBR  \
# 0       100636                 Community College of the Air Force     AL
# 1       100654                           Alabama A & M University     AL
# 2       100663                University of Alabama at Birmingham     AL
# 3       100672             ALABAMA AVIATION AND TECHNICAL COLLEGE     AL
# 4       100690                                 Amridge University     AL
# 5       100706                University of Alabama in Huntsville     AL
# 6       100724                           Alabama State University     AL
# 7       100751                          The University of Alabama     AL
# 8       100760                  Central Alabama Community College     AL
# 9       100812                            Athens State University     AL
# 10      100830                    Auburn University at Montgomery     AL
# 11      100858                                  Auburn University     AL
# ...

# %% [markdown]
# You would use an empty list and append the yearly dataframes to the list. "Fin" is our new dataframe that only includes the required columns.

# %% [markdown]
# explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

# %%
fin.head(5)
# Out:
#    UNITID                                  INSTNM STABBR         ZIP  REGION  \
# 0  100636      Community College of the Air Force     AL  36114-3011     0.0
# 1  100654                Alabama A & M University     AL       35762     5.0
# 2  100663     University of Alabama at Birmingham     AL  35294-0110     5.0
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL       36360     5.0
# 4  100690                      Amridge University     AL  36117-3553     5.0
#
#    ADM_RATE  TUITIONFEE_IN
# 0       NaN            NaN
# 1       NaN            NaN
# 2       NaN            NaN
# 3       NaN            NaN
# 4       NaN            NaN

# %%
fin.tail(5)
# Out:
#         UNITID                                    INSTNM STABBR        ZIP  \
# 6801  48511112         Georgia Military College - Dublin     GA  310215149
# 6802  48511113        Georgia Military College - Eastman     GA  310236109
# 6803  48616901  American College of Barbering - Florence     KY  410421801
# 6804  49005401      HCI College - Fort Lauderdale Campus     FL      33309
# 6805  49146401          ABC Adult School - Cabrillo Lane     CA  907037748
#
#       REGION  ADM_RATE  TUITIONFEE_IN
# 6801     5.0       NaN         6120.0
# 6802     5.0       NaN         6120.0
# 6803     5.0       NaN            NaN
# 6804     5.0       NaN        21420.0
# 6805     8.0       NaN            NaN

# %%
fin.sample(2)
# Out:
#       UNITID                                         INSTNM STABBR    ZIP  \
# 5598  444042         National University College-Rio Grande     PR  00745
# 5317  372240  Universal College of Beauty Inc-Los Angeles 2     CA  90008
#
#       REGION  ADM_RATE  TUITIONFEE_IN
# 5598     9.0    0.9832         6495.0
# 5317     8.0       NaN            NaN

# %%
fin.isnull()

# %% [markdown]
# Wherever there is true in tha above code, it means that that has NAN value. Now it is not possible to do any visualization with the NAN values so we fill them with 0 in order to visualize

# %%
fin.fillna(0)

# %% [markdown]
# This will help us to read the data well.

# %% [markdown]
# the dataframe contains many years of data of all U.S. colleges.
#  let's just look at UMBC

# %%
fin1 = fin.loc[fin["INSTNM"] == 'University of Maryland-Baltimore County']

# %% [markdown]
# filter/query the dataframe to retrieve only rows that belong to UMBC
# save the UMNC data to a new data frame. using a new variable

# %%
print(fin1)
# Out:
#       UNITID                                   INSTNM STABBR    ZIP  REGION  \
# 2151  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 2049  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1982  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1955  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1926  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1915  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1893  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1873  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1830  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1819  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1799  163268  University of Maryland-Baltimore County     MD  21250     2.0
# ...

# %% [markdown]
# Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

# %%
fin1.head()
# Out:
#       UNITID                                   INSTNM STABBR    ZIP  REGION  \
# 2151  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 2049  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1982  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1955  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1926  163268  University of Maryland-Baltimore County     MD  21250     2.0
#
#       ADM_RATE  TUITIONFEE_IN
# 2151       NaN            NaN
# 2049       NaN            NaN
# 1982       NaN            NaN
# 1955       NaN            NaN
# 1926       NaN         5490.0

# %%
fin1.tail()
# Out:
#       UNITID                                   INSTNM STABBR    ZIP  REGION  \
# 1610  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1555  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1510  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1478  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1415  163268  University of Maryland-Baltimore County     MD  21250     2.0
#
#       ADM_RATE  TUITIONFEE_IN
# 1610    0.5961        10384.0
# 1555    0.5942        11006.0
# 1510    0.5683        11264.0
# 1478    0.6021        11518.0
# 1415    0.5794        11778.0

# %%
fin1.sample()
# Out:
#       UNITID                                   INSTNM STABBR    ZIP  REGION  \
# 1767  163268  University of Maryland-Baltimore County     MD  21250     2.0
#
#       ADM_RATE  TUITIONFEE_IN
# 1767    0.7174         8780.0

# %%
fin1.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN
# count      23.0    23.0  18.000000      19.000000
# mean   163268.0     2.0   0.640694    9004.842105
# std         0.0     0.0   0.052728    1825.795421
# min    163268.0     2.0   0.568300    5490.000000
# 25%    163268.0     2.0   0.597600    8270.000000
# 50%    163268.0     2.0   0.632100    8872.000000
# 75%    163268.0     2.0   0.689375   10226.000000
# max    163268.0     2.0   0.717400   11778.000000

# %%
fin1.isnull()
# Out:
#       UNITID  INSTNM  STABBR    ZIP  REGION  ADM_RATE  TUITIONFEE_IN
# 2151   False   False   False  False   False      True           True
# 2049   False   False   False  False   False      True           True
# 1982   False   False   False  False   False      True           True
# 1955   False   False   False  False   False      True           True
# 1926   False   False   False  False   False      True          False
# 1915   False   False   False  False   False     False          False
# 1893   False   False   False  False   False     False          False
# 1873   False   False   False  False   False     False          False
# 1830   False   False   False  False   False     False          False
# 1819   False   False   False  False   False     False          False
# 1799   False   False   False  False   False     False          False
# 1779   False   False   False  False   False     False          False
# 1767   False   False   False  False   False     False          False
# ...

# %% [markdown]
# The first few rows have NAN values. In order to make it a clean data, lets add zero in place of NAN

# %%
fin1.fillna(0)
# Out:
#       UNITID                                   INSTNM STABBR    ZIP  REGION  \
# 2151  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 2049  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1982  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1955  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1926  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1915  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1893  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1873  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1830  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1819  163268  University of Maryland-Baltimore County     MD  21250     2.0
# 1799  163268  University of Maryland-Baltimore County     MD  21250     2.0
# ...

# %% [markdown]
# Plot UMBC's in-state tution overtime from 1996 to 2019 using Bar Chart

# %% [markdown]
# Before we do that, let's manually add the year next to the tution fee in order to plot

# %%
fin1.insert(6, "Year", [1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018], True)

# %% [markdown]
# Let's plot now by importing various Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fin1.plot.scatter(x='Year',y='TUITIONFEE_IN')

# %% [markdown]
# Plot UMBC's in-state tution overtime from 1996 to 2019 using Line Chart

# %%
lines = fin1.plot.line(x='Year', y='TUITIONFEE_IN')

# %% [markdown]
# So my technique of doing so was to just extract the tution fee and fine the growth change. What happens with this is that when we have less columns, we make less mess. There are less chances of error and plotting becomes very easy. Now as there was no specific instructions that I cannot extract the tution fee from the dataset and put it in another dataset, I went ahead and used that technique by documenting each step as it goes. I was able to plot the growth rate with no error

# %% [markdown]
#  Now let's look at the tuition growth rate year over year
# We need to calculate UMBC tuition change percentage each year
# First convert the TUITIONFEE_IN column to a Python List

# %% [markdown]
# Let's extract the Tution fee and put it in another Dataset to calculate the growth

# %%
df_percentage2= fin1[['TUITIONFEE_IN']]

# %% [markdown]
# Now that we have extracted it, let's go ahead and find the growth rate

# %%
growth_rate= df_percentage2.pct_change()*100

# %% [markdown]
# The first few rates are NAN as there are no values. This is not good enough to be plotted on the graph. Let's put zero wherever there is NAN

# %%
growth_rate.fillna(0)

# %% [markdown]
# This is just a lot of decimal, let's round it off upto 2

# %%
growth_rate.round(2)

# %% [markdown]
# Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")
# Not as hard as you may think. If you get stuck, you think too hard.
# Google it and you will find the answer.

# %%
PCT_CHANGE = growth_rate.round(2)

# %%
PCT_CHANGE
# Out:
#       TUITIONFEE_IN
# 2151            NaN
# 2049            NaN
# 1982            NaN
# 1955            NaN
# 1926            NaN
# 1915           7.65
# 1893           7.65
# 1873          16.13
# 1830           8.55
# 1819           6.23
# 1799           1.20
# 1779           1.00
# 1767           0.83
# 1745           1.05
# 1710           3.37
# 1694           3.23
# 1660           3.14
# 1629           3.11
# 1610           3.14
# 1555           5.99
# 1510           2.34
# 1478           2.25
# 1415           2.26

# %% [markdown]
# Finaly, we can make the plot tuition growth rate year over year - bar first, then line chart

# %% [markdown]
# Let's add year first

# %%
PCT_CHANGE.insert(1, "Year", [1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018], True)

# %%
lines = PCT_CHANGE.plot.line(x='Year', y='TUITIONFEE_IN')

# %% [markdown]
# the dataframe contains many years of data of all U.S. colleges.
# let's just look at JHU
# filter/query the dataframe to retrieve only rows that belong to JHU
# save the JHU data to a new data frame. using a new variable
# so that the old big data frame is still available for later use.

# %%
fin2 = fin.loc[fin["INSTNM"] == 'Johns Hopkins University']

# %%
fin2.insert(6, "Year", [1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018], True)

# %%
fin2
# Out:
#       UNITID                    INSTNM STABBR         ZIP  REGION  ADM_RATE  \
# 2139  162928  Johns Hopkins University     MD  21218-2688     2.0       NaN
# 2039  162928  Johns Hopkins University     MD  21218-2688     2.0       NaN
# 1973  162928  Johns Hopkins University     MD  21218-2688     2.0       NaN
# 1946  162928  Johns Hopkins University     MD  21218-2688     2.0       NaN
# 1917  162928  Johns Hopkins University     MD  21218-2688     2.0       NaN
# 1906  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3431
# 1884  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3506
# 1865  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3060
# 1823  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3071
# 1812  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3509
# 1792  162928  Johns Hopkins University     MD  21218-2688     2.0    0.2792
# ...

# %% [markdown]
# Let's clean the data by adding 0 in replace to NAN

# %%
fin2.fillna(0)
# Out:
#       UNITID                    INSTNM STABBR         ZIP  REGION  ADM_RATE  \
# 2139  162928  Johns Hopkins University     MD  21218-2688     2.0    0.0000
# 2039  162928  Johns Hopkins University     MD  21218-2688     2.0    0.0000
# 1973  162928  Johns Hopkins University     MD  21218-2688     2.0    0.0000
# 1946  162928  Johns Hopkins University     MD  21218-2688     2.0    0.0000
# 1917  162928  Johns Hopkins University     MD  21218-2688     2.0    0.0000
# 1906  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3431
# 1884  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3506
# 1865  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3060
# 1823  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3071
# 1812  162928  Johns Hopkins University     MD  21218-2688     2.0    0.3509
# 1792  162928  Johns Hopkins University     MD  21218-2688     2.0    0.2792
# ...

# %% [markdown]
# Plot JHU's in-state tuition overtime from 1996 to 2019.
# Let's plot bar and line chart together

# %%
fin2.plot.scatter(x='Year',y='TUITIONFEE_IN')

# %%
lines = fin2.plot.line(x='Year', y='TUITIONFEE_IN')

# %% [markdown]
# Let's calculate the JHU tuition percentge growth using the function defined earlier

# %%
df_percentage3= fin2[['TUITIONFEE_IN']]

# %%
PCT_CHANGE2 = df_percentage3.pct_change()*100

# %% [markdown]
# Let's change all NAN values to zero in order to plot and round it off to 2

# %%
PCT_CHANGE2.fillna(0)
# Out:
#       TUITIONFEE_IN
# 2139       0.000000
# 2039       0.000000
# 1973       0.000000
# 1946       0.000000
# 1917       0.000000
# 1906       5.134376
# 1884       4.502098
# 1865       4.892296
# 1823       4.907762
# 1812       4.910418
# 1792       7.210626
# 1772       5.899705
# 1760       5.013928
# 1738       3.846154
# 1703       3.908046
# 1687       3.933137
# 1653       2.625355
# 1622       4.793731
# 1603       3.496811
# 1548       3.506162
# 1503       3.490043
# 1473       3.491371
# 1410       3.009392

# %%
PCT_CHANGE2.round(2)
# Out:
#       TUITIONFEE_IN
# 2139            NaN
# 2039            NaN
# 1973            NaN
# 1946            NaN
# 1917            NaN
# 1906           5.13
# 1884           4.50
# 1865           4.89
# 1823           4.91
# 1812           4.91
# 1792           7.21
# 1772           5.90
# 1760           5.01
# 1738           3.85
# 1703           3.91
# 1687           3.93
# 1653           2.63
# 1622           4.79
# 1603           3.50
# 1548           3.51
# 1503           3.49
# 1473           3.49
# 1410           3.01

# %%
PCT_CHANGE2.insert(1, "Year", [1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018], True)

# %%
Make a bar plot of the JHU percentage changes tuitions over time

# %%
from matplotlib import pyplot as plt

# %%
PCT_CHANGE2.plot(kind='bar',x='Year',y='TUITIONFEE_IN')

# %% [markdown]
# In order to plot both UMBC and JHU tuition change over time in the same plot,
# we need to combine the two datasets using the common key of YEAR
# First make a umbc2 dataframe with only two columns needed. WE don't need other columns.
# Also change the column name from "PCT_CHANGE" to "UMBC_PCT" in preparation for the merge.
# This is because both umbc and jhu dataframe have the same column name "PCT_CHANGE",
# We rename them to there is no collision during the merge. BTW, Pandas handles collision gracefully,
# Feel free to try it without changing the column names.

# %% [markdown]
# Using the technique that I used before, now I don't have to drop any columns as my dataset is very clear and it only includes the tution fee. I have taken the year column as a base and combied both of them into one dataframe.

# %%
merged_data= pd.merge(PCT_CHANGE, PCT_CHANGE2, on="Year")

# %% [markdown]
# Now, merger the two data frames
# and display the new dataframe

# %%
merged_data.rename(columns={'TUITIONFEE_IN_x': 'UMBC_PCT', 'TUITIONFEE_IN_y': 'JHU_PCT'}, inplace=True)

# %%
merged_data
# Out:
#     UMBC_PCT  Year   JHU_PCT
# 0        NaN  1996       NaN
# 1        NaN  1997       NaN
# 2        NaN  1998       NaN
# 3        NaN  1999       NaN
# 4        NaN  2000       NaN
# 5       7.65  2001  5.134376
# 6       7.65  2002  4.502098
# 7      16.13  2003  4.892296
# 8       8.55  2004  4.907762
# 9       6.23  2005  4.910418
# 10      1.20  2006  7.210626
# 11      1.00  2007  5.899705
# 12      0.83  2008  5.013928
# 13      1.05  2009  3.846154
# 14      3.37  2010  3.908046
# 15      3.23  2011  3.933137
# 16      3.14  2012  2.625355
# 17      3.11  2013  4.793731
# 18      3.14  2014  3.496811
# 19      5.99  2015  3.506162
# 20      2.34  2016  3.490043
# 21      2.25  2017  3.491371
# 22      2.26  2018  3.009392

# %% [markdown]
#  Plot UMBC and JHU separately on the same plot
#  However, this does not work since the bars overlap.

# %%
fig, ax = plt.subplots()
merged_data.plot(x = 'Year', y = 'UMBC_PCT', ax = ax) 
merged_data.plot(x = 'Year', y = 'JHU_PCT', ax = ax, secondary_y = True)

# %%
merged_data.set_index('Year').plot.bar()

# %% [markdown]
# Looking at the trend it shows that UMBC had much higher rate in the change in the tution fee than JHU. UMBC is ranked 160 in Ntional University and JHU is ranked 9 in the same list. Overall UMBC's growth rate is less than JHU in most years except the begining of the years.
